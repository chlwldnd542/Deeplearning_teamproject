# %% [markdown]
# #### I. 바운딩 박스 크롭 및 패딩(데이터 전처리)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.applications import VGG16
import numpy as np
import os
from sklearn.model_selection import train_test_split
import pandas as pd

# 데이터 디렉토리 설정
data_dir = '/content/drive/MyDrive/DL/project/Teamproject/padded_images'

# 클래스 이름을 폴더 이름과 동일하게 설정
classes = ['tie_abnormal', 'tie_normal']

# 모든 이미지 경로와 레이블 가져오기
all_images = []
all_labels = []
for class_name in classes:
    class_dir = os.path.join(data_dir, class_name)
    for fname in os.listdir(class_dir):
        if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
            all_images.append(os.path.join(class_dir, fname))
            all_labels.append(class_name)

# 데이터를 학습, 검증, 테스트 세트로 분할
train_images, test_images, train_labels, test_labels = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.25, random_state=42)
print(len(train_labels), len(val_labels), len(test_labels))
# Out:
# 14688 4896 4897

# %%
import json
import os
from PIL import Image
import glob

# 상위 폴더 경로 설정
base_json_dir = '/content/drive/My Drive/Deeplearning/Teamproject/TL_일반철도_이상'
base_image_dir = '/content/drive/My Drive/Deeplearning/Teamproject/원천_folder'
output_dir = '/content/drive/My Drive/Deeplearning/Teamproject/cropped_images'

# 출력 폴더 내 클래스 및 상태별 폴더 생성 함수
def create_folders(categories, base_dir):
    for cat_id, cat_name in categories.items():
        os.makedirs(os.path.join(base_dir, f'{cat_name}_normal'), exist_ok=True)
        os.makedirs(os.path.join(base_dir, f'{cat_name}_abnormal'), exist_ok=True)

# JSON 파일 처리 함수
def process_json_file(json_file_path, image_file_path, categories, output_dir):
    with open(json_file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # 바운딩 박스와 클래스 정보 가져오기
    annotations = data['annotations']
    bounding_boxes_info = [
        {
            'bbox': ann['bbox'],
            'category': categories.get(ann['category_id'], 'Unknown'),
            'status': ann.get('status', 'unknown')  # 'status' 필드를 가져옵니다.
        }
        for ann in annotations if 'bbox' in ann and ann['bbox']
    ]

    # 이미지 열기
    image = Image.open(image_file_path)

    # 바운딩 박스별로 크롭하고 저장
    for idx, bbox_info in enumerate(bounding_boxes_info):
        bbox = bbox_info['bbox']
        category = bbox_info['category']
        status = bbox_info['status']
        left, top, width, height = bbox
        right = left + width
        bottom = top + height

        # Unknown 카테고리 무시
        if category == 'Unknown':
            continue

        # 바운딩 박스 크롭
        cropped_image = image.crop((left, top, right, bottom))

        # 상태에 따른 폴더 결정
        if status == 'normal':
            save_dir = os.path.join(output_dir, f'{category}_normal')
        elif status == 'abnormal':
            save_dir = os.path.join(output_dir, f'{category}_abnormal')
        else:
            continue  # status가 정상 또는 비정상이 아닌 경우 무시

        # 저장 경로 설정
        save_path = os.path.join(save_dir, f'{category}_{os.path.splitext(os.path.basename(json_file_path))[0]}_{idx}.jpg')
2.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2552858_3.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2552858_4.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2552858_5.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2552858_6.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2552858_7.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553262_0.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553262_1.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553262_2.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553262_3.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553262_6.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553262_7.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명8_2553262_8.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553265_0.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553265_1.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553265_2.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553265_3.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553265_6.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553265_7.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명8_2553265_8.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2552834_0.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명8_2552834_1.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2552834_2.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2552834_3.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2552834_4.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2552834_5.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2552834_6.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2552834_9.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553050_0.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553050_1.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553050_2.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명8_2553050_3.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명8_2553050_4.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553050_5.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/fishplate_normal/fishplate_일반철도_220831_광명8_2553050_6.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명8_2553050_7.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553050_8.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553050_10.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553050_11.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553050_13.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553043_0.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553043_2.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553043_3.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553043_4.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명8_2553043_5.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명8_2553043_6.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명8_2553043_7.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명8_2553043_8.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553043_9.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553043_11.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/fishplate_normal/fishplate_일반철도_220831_광명8_2553043_12.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명8_2553043_13.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명8_2553043_14.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명8_2553043_15.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명8_2553043_16.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553043_17.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명8_2553043_18.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553043_19.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553043_20.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553051_0.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553051_1.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553051_3.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553051_4.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553051_5.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553051_7.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553051_8.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명8_2553051_9.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/fishplate_normal/fishplate_일반철도_220831_광명8_2553051_10.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명8_2553049_0.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553049_1.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명8_2553049_2.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명8_2553049_3.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553049_4.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명8_2553049_5.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명8_2553049_6.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/fishplate_normal/fishplate_일반철도_220831_광명8_2553049_7.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명8_2553049_8.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553049_9.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553049_11.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553049_12.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553049_14.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명8_2553266_0.jpg
# ...
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명5_2532307_17.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명5_2532307_18.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명5_2532307_19.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명5_2532307_20.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명5_2532307_21.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명5_2532307_22.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명5_2532307_23.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명5_2532307_24.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명4_2544883_0.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명4_2544883_1.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명4_2544883_4.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명4_2544883_5.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명4_2544883_6.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명4_2544883_7.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명4_2544892_0.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명4_2544892_1.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/fishplate_normal/fishplate_일반철도_220831_광명4_2544892_3.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명4_2544892_4.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명4_2544892_5.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명4_2544892_6.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명4_2544892_7.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명4_2544892_8.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명4_2544892_9.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명4_2544892_10.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명4_2544892_11.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명4_2544892_12.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532389_0.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532389_1.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532389_3.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532389_4.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532389_6.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532389_7.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532389_9.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532389_11.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532389_12.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532389_14.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532389_15.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532389_17.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명5_2532389_18.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명5_2532389_19.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명5_2532389_20.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532396_0.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532396_1.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532396_3.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532396_4.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532396_6.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532396_7.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532396_9.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532396_11.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532396_12.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532396_14.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532396_15.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532396_17.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명5_2532396_18.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명5_2532396_19.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명5_2532396_20.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명4_2544666_0.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명4_2544666_1.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명4_2544666_2.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명4_2544666_5.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명4_2544898_0.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명4_2544898_1.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명4_2544898_4.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_normal/tie_일반철도_220831_광명4_2544898_5.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명4_2544898_6.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532298_2.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532298_3.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532298_4.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532298_5.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532298_6.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532298_7.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532298_8.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/pandrol_e-clip_normal/pandrol_e-clip_일반철도_220831_광명5_2532298_9.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/fishplate_normal/fishplate_일반철도_220831_광명5_2532298_10.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/fishplate_normal/fishplate_일반철도_220831_광명5_2532298_11.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명5_2532298_12.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명5_2532298_13.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명5_2532298_14.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명5_2532298_15.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명5_2532298_16.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명5_2532298_17.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명5_2532298_18.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/bolt-nut_normal/bolt-nut_일반철도_220831_광명5_2532298_19.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명5_2532298_20.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명5_2532298_21.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명5_2532298_22.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명5_2532298_23.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명5_2532298_24.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명5_2532298_25.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명5_2532298_26.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/screw_spike_normal/screw_spike_일반철도_220831_광명5_2532298_27.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명5_2532298_28.jpg
# Saved cropped image to /content/drive/My Drive/Deeplearning/Teamproject/cropped_images/tie_abnormal/tie_일반철도_220831_광명5_2532298_29.jpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-4bc218735b10> in <cell line: 77>()
#      80
#      81     if os.path.exists(image_file_path):
# ---> 82         process_json_file(json_file, image_file_path, categories, output_dir)
#      83     else:
#      84         print(f'Image file {image_file_path} does not exist.')
#
# <ipython-input-6-4bc218735b10> in process_json_file(json_file_path, image_file_path, categories, output_dir)
#      60         # 저장 경로 설정
#      61         save_path = os.path.join(save_dir, f'{category}_{os.path.splitext(os.path.basename(json_file_path))[0]}_{idx}.jpg')
# ---> 62         cropped_image.save(save_path)
#      63         print(f'Saved cropped image to {save_path}')
#      64
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2429
#    2430         try:
# -> 2431             save_handler(self, fp, filename)
#    2432         except Exception:
#    2433             if open_fp:
#
# /usr/local/lib/python3.10/dist-packages/PIL/JpegImagePlugin.py in _save(im, fp, filename)
#     638     if im.width == 0 or im.height == 0:
#     639         msg = "cannot write empty image as JPEG"
# --> 640         raise ValueError(msg)
#     641
#     642     try:
#
# ValueError: cannot write empty image as JPEG

# %%
from google.colab import drive
import os
from PIL import Image, ImageOps

# Google Drive 마운트
drive.mount('/content/gdrive')

def pad_image(image, size):
    # 이미지를 원하는 크기로 패딩합니다
    return ImageOps.pad(image, size, method=Image.BICUBIC, color=(0, 0, 0), centering=(0.5, 0.5))

def process_directory(directory, output_directory, size):
    if not os.path.exists(directory):
        print(f"Directory not found: {directory}")
        return

    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    processed_files = set(os.listdir(output_directory))
    processed_count = 0

    for filename in os.listdir(directory):
        if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp')) and filename not in processed_files:
            img_path = os.path.join(directory, filename)
            try:
                img = Image.open(img_path)
                padded_img = pad_image(img, size)
                padded_img.save(os.path.join(output_directory, filename))
                processed_count += 1
            except Exception as e:
                print(f"Error processing file {filename}: {e}")

    return processed_count

# 디렉토리와 크기 정의
normal_path = '/content/gdrive/MyDrive/DL/project/Teamproject/cropped_images/tie_normal'
abnormal_path = '/content/gdrive/MyDrive/DL/project/Teamproject/cropped_images/tie_abnormal'

normal_output_path = '/content/gdrive/MyDrive/DL/project/Teamproject/padded_images/tie_normal'
abnormal_output_path = '/content/gdrive/MyDrive/DL/project/Teamproject/padded_images/tie_abnormal'

desired_size = (224, 224)  # 추천 사이즈

# 경로 존재 여부 확인 및 경로 출력
print(f"Normal Path: {normal_path}, Exists: {os.path.exists(normal_path)}")
print(f"Abnormal Path: {abnormal_path}, Exists: {os.path.exists(abnormal_path)}")
print(f"Normal Output Path: {normal_output_path}, Exists: {os.path.exists(normal_output_path)}")
print(f"Abnormal Output Path: {abnormal_output_path}, Exists: {os.path.exists(abnormal_output_path)}")

# 디렉토리 처리
normal_processed = process_directory(normal_path, normal_output_path, desired_size)
abnormal_processed = process_directory(abnormal_path, abnormal_output_path, desired_size)

print('Normal images padded and saved:', normal_processed)
print('Abnormal images padded and saved:', abnormal_processed)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Normal Path: /content/gdrive/MyDrive/DL/project/Teamproject/cropped_images/tie_normal, Exists: True
# Abnormal Path: /content/gdrive/MyDrive/DL/project/Teamproject/cropped_images/tie_abnormal, Exists: True
# Normal Output Path: /content/gdrive/MyDrive/DL/project/Teamproject/padded_images/tie_normal, Exists: True
# Abnormal Output Path: /content/gdrive/MyDrive/DL/project/Teamproject/padded_images/tie_abnormal, Exists: True
